# %% [markdown]
# ## **COMPUTATIONAL DRUG DISCOVERY**

# %% [markdown]
# **PART 1(DOWNLOAD THE BIOACTIVITY DATA)**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %% [markdown]
# # **Installing Libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioativity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.10/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # **Search for Target Protein**

# %% [markdown]
# **Target search for cancer**

# %%
# Code to search cancer targets in chembl database
target = new_client.target
target_query = target.search('Phd fingers')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references      organism  \
# 0                 []  Homo sapiens
# 1                 []  Homo sapiens
# 2                 []  Homo sapiens
# 3                 []  Homo sapiens
# 4                 []  Homo sapiens
# ..               ...           ...
# 161               []  Homo sapiens
# 162               []  Homo sapiens
# 163               []  Homo sapiens
# 164               []  Homo sapiens
# 165               []  Homo sapiens
#
#                                              pref_name  score  \
# 0                                PHD finger protein 13   16.0
# 1                                PHD finger protein 23   14.0
# 2      Bromodomain and PHD finger-containing protein 3   13.0
# 3                                             Peregrin   13.0
# 4                     Lysine-specific demethylase PHF2   12.0
# ..                                                 ...    ...
# 161  Baculoviral IAP repeat-containing protein 2/Al...    2.0
# 162                  E3 ubiquitin-protein ligase CBL-B    2.0
# 163                     CRL4(CRBN) E3 ubiquitin ligase    1.0
# 164  Baculoviral IAP repeat-containing protein 2/BC...    1.0
# 165  Baculoviral IAP repeat-containing protein 2/Pr...    1.0
#
#      species_group_flag target_chembl_id  \
# 0                 False    CHEMBL1764945
# 1                 False    CHEMBL2424508
# 2                 False    CHEMBL3108644
# 3                 False    CHEMBL3132741
# 4                 False    CHEMBL4295672
# ..                  ...              ...
# 161               False    CHEMBL4802032
# 162               False    CHEMBL4879459
# 163               False    CHEMBL3833061
# 164               False    CHEMBL4296119
# 165               False    CHEMBL4802030
#
#                                      target_components  \
# 0    [{'accession': 'Q86YI8', 'component_descriptio...
# 1    [{'accession': 'Q9BUL5', 'component_descriptio...
# 2    [{'accession': 'Q9ULD4', 'component_descriptio...
# 3    [{'accession': 'P55201', 'component_descriptio...
# 4    [{'accession': 'O75151', 'component_descriptio...
# ..                                                 ...
# 161  [{'accession': 'P15121', 'component_descriptio...
# 162  [{'accession': 'Q13191', 'component_descriptio...
# 163  [{'accession': 'Q96SW2', 'component_descriptio...
# 164  [{'accession': 'P00519', 'component_descriptio...
# 165  [{'accession': 'Q13490', 'component_descriptio...
#
#                      target_type  tax_id
# 0                 SINGLE PROTEIN    9606
# 1                 SINGLE PROTEIN    9606
# 2                 SINGLE PROTEIN    9606
# 3                 SINGLE PROTEIN    9606
# 4                 SINGLE PROTEIN    9606
# ..                           ...     ...
# 161  PROTEIN-PROTEIN INTERACTION    9606
# 162               SINGLE PROTEIN    9606
# 163              PROTEIN COMPLEX    9606
# 164  PROTEIN-PROTEIN INTERACTION    9606
# 165  PROTEIN-PROTEIN INTERACTION    9606
#
# [166 rows x 9 columns]

# %% [markdown]
# ## Select and retrieve bioactivity data for PHD finger protein 23

# %% [markdown]
# **We will assign the 1st entry**

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL2424508'

# %% [markdown]
# **Now we will retrieve only bioactivity data for PHD finger protein 13(CHEMBL2424508) that are reported as IC50 values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type = "IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     13444773                  []
# 1         None             None     13444774                  []
# 2         None             None     13444775                  []
# 3         None             None     13444776                  []
# 4         None             None     13444777                  []
# ..         ...              ...          ...                 ...
# 76        None             None     13965841                  []
# 77        None             None     13965842                  []
# 78        None             None     13965843                  []
# 79        None             None     13965844                  []
# 80        None             None     13965845                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 1    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 2    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 3    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 4    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# ..             ...                                                ...
# 76   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 77   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 78   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 79   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 80   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 76          B                    None                   None  BAO_0000190
# 77          B                    None                   None  BAO_0000190
# 78          B                    None                   None  BAO_0000190
# 79          B                    None                   None  BAO_0000190
# 80          B                    None                   None  BAO_0000190
#
#     ... target_organism       target_pref_name target_tax_id text_value  toid  \
# 0   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 1   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 2   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 3   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 4   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# ..  ...             ...                    ...           ...        ...   ...
# 76  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 77  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 78  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 79  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 80  ...    Homo sapiens  PHD finger protein 23          9606       None  None
#
#     type units    uo_units upper_value value
# 0   IC50    uM  UO_0000065        None  10.0
# 1   IC50    uM  UO_0000065        None  10.0
# 2   IC50    uM  UO_0000065        None  10.0
# 3   IC50    uM  UO_0000065        None  10.0
# 4   IC50    uM  UO_0000065        None  10.0
# ..   ...   ...         ...         ...   ...
# 76  IC50    uM  UO_0000065        None  30.0
# 77  IC50    uM  UO_0000065        None  30.0
# 78  IC50    uM  UO_0000065        None  30.0
# 79  IC50    uM  UO_0000065        None  30.0
# 80  IC50    uM  UO_0000065        None  30.0
#
# [81 rows x 46 columns]

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     13444773                  []
# 1        None             None     13444774                  []
# 2        None             None     13444775                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 1   CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 2   CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism       target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  PHD finger protein 23          9606       None  None  IC50
# 1    Homo sapiens  PHD finger protein 23          9606       None  None  IC50
# 2    Homo sapiens  PHD finger protein 23          9606       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None  10.0
# 1    uM  UO_0000065        None  10.0
# 2    uM  UO_0000065        None  10.0
#
# [3 rows x 46 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally we will save the resulting bioactivity data to a CSV file "bioactivity_data.csv"**

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# # **What we have so far in the CSV file**

# %%
# !ls
# Out:
# bioactivity_data.csv  sample_data

# %% [markdown]
# ***See what i have extract so far***

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,13444773,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)c(Nc4ccccc4)c3)cc2C1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2424677,,CHEMBL2424677,,0,http://www.openphacts.org/units/Nanomolar,1919666,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444774,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)cc3Nc3ccccc3)cc2C1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426376,,CHEMBL2426376,,0,http://www.openphacts.org/units/Nanomolar,1919665,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444775,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)cc3)cc2C1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426375,,CHEMBL2426375,,0,http://www.openphacts.org/units/Nanomolar,1919664,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444776,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CC5CCC(C4)C5N4CCCC4)cc3)cc2C1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426374,,CHEMBL2426374,,0,http://www.openphacts.org/units/Nanomolar,1919663,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444777,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(N5CCCC5)CC4)cc3)cc2C1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426373,,CHEMBL2426373,,0,http://www.openphacts.org/units/Nanomolar,1919662,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444778,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(-c2ccccc2)c1)N1CCC(N2CCCC2)CC1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426368,,CHEMBL2426368,,0,http://www.openphacts.org/units/Nanomolar,1919657,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444779,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Oc2ccccc2)c1)N1CCC(N2CCCC2)CC1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426367,,CHEMBL2426367,,0,http://www.openphacts.org/units/Nanomolar,1919656,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444780,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Cc2ccccc2)c1)N1CCC(N2CCCC2)CC1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426366,,CHEMBL2426366,,0,http://www.openphacts.org/units/Nanomolar,1919655,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0
# ,,13444781,[],CHEMBL2429071,Inhibition of PHF23 (unknown origin) after 30 mins by AlphaScreen assay,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(NCc2ccccc2)c1)N1CCC(N2CCCC2)CC1,,,CHEMBL2424619,J Med Chem,2013,,CHEMBL2426365,,CHEMBL2426365,,0,http://www.openphacts.org/units/Nanomolar,1919654,>,1,1,>,,IC50,nM,,10000.0,CHEMBL2424508,Homo sapiens,PHD finger protein 23,9606,,,IC50,uM,UO_0000065,,10.0

# %% [markdown]
# # **Handling Missing Data**

# %% [markdown]
# If any compounds has a missing value for the 'standard_value' column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None     13444773                  []
# 1         None             None     13444774                  []
# 2         None             None     13444775                  []
# 3         None             None     13444776                  []
# 4         None             None     13444777                  []
# ..         ...              ...          ...                 ...
# 76        None             None     13965841                  []
# 77        None             None     13965842                  []
# 78        None             None     13965843                  []
# 79        None             None     13965844                  []
# 80        None             None     13965845                  []
#
#    assay_chembl_id                                  assay_description  \
# 0    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 1    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 2    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 3    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# 4    CHEMBL2429071  Inhibition of PHF23 (unknown origin) after 30 ...
# ..             ...                                                ...
# 76   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 77   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 78   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 79   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
# 80   CHEMBL3136677  Inhibition of GST-tagged PHF23 (unknown origin...
#
#    assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0           B                    None                   None  BAO_0000190
# 1           B                    None                   None  BAO_0000190
# 2           B                    None                   None  BAO_0000190
# 3           B                    None                   None  BAO_0000190
# 4           B                    None                   None  BAO_0000190
# ..        ...                     ...                    ...          ...
# 76          B                    None                   None  BAO_0000190
# 77          B                    None                   None  BAO_0000190
# 78          B                    None                   None  BAO_0000190
# 79          B                    None                   None  BAO_0000190
# 80          B                    None                   None  BAO_0000190
#
#     ... target_organism       target_pref_name target_tax_id text_value  toid  \
# 0   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 1   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 2   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 3   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 4   ...    Homo sapiens  PHD finger protein 23          9606       None  None
# ..  ...             ...                    ...           ...        ...   ...
# 76  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 77  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 78  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 79  ...    Homo sapiens  PHD finger protein 23          9606       None  None
# 80  ...    Homo sapiens  PHD finger protein 23          9606       None  None
#
#     type units    uo_units upper_value value
# 0   IC50    uM  UO_0000065        None  10.0
# 1   IC50    uM  UO_0000065        None  10.0
# 2   IC50    uM  UO_0000065        None  10.0
# 3   IC50    uM  UO_0000065        None  10.0
# 4   IC50    uM  UO_0000065        None  10.0
# ..   ...   ...         ...         ...   ...
# 76  IC50    uM  UO_0000065        None  30.0
# 77  IC50    uM  UO_0000065        None  30.0
# 78  IC50    uM  UO_0000065        None  30.0
# 79  IC50    uM  UO_0000065        None  30.0
# 80  IC50    uM  UO_0000065        None  30.0
#
# [81 rows x 46 columns]

# %% [markdown]
# **Apparently for this dataset there is no missing data. But it is important to use this cell in case there are imputs without the standard_value column.**

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# **Iterate the 'molecule_chembl_id', 'canonical_smiles' and 'standard_value' to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# # **Combine the lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class,standard_value))
df3 = pd.DataFrame(data_tuples, columns = ['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL2424677  CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)...
# 1       CHEMBL2426376  CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)...
# 2       CHEMBL2426375  CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)...
# 3       CHEMBL2426374  CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CC5CCC(C4)C5N4CC...
# 4       CHEMBL2426373  CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(N5CCCC5)CC4)...
# ..                ...                                                ...
# 76      CHEMBL3134132              c1cc(N2CCC(N3CCCCC3)CC2)ccc1CCN1CCCC1
# 77      CHEMBL2426364  O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Nc2ccccc2)c...
# 78      CHEMBL2426474  O=C(c1ccc(C(=O)N2CCC(N3CCCCC3)CC2)cc1)N1CCC(N2...
# 79      CHEMBL1235119                 O=C(c1cncc(Br)c1)N1CCC(N2CCCC2)CC1
# 80      CHEMBL3134131               c1cc(N2CCC(N3CCCC3)CC2)ccc1CCN1CCCC1
#
#    bioactivity_class standard_value
# 0           inactive        10000.0
# 1           inactive        10000.0
# 2           inactive        10000.0
# 3           inactive        10000.0
# 4           inactive        10000.0
# ..               ...            ...
# 76          inactive        30000.0
# 77          inactive        30000.0
# 78          inactive        30000.0
# 79          inactive        30000.0
# 80          inactive        30000.0
#
# [81 rows x 4 columns]

# %% [markdown]
# # **Save the DataFrame to CSV file**

# %%
df3.to_csv('bioactivity_pre-processed_data.csv' , index=False)

# %%
# !ls
# Out:
# bioactivity_data.csv  bioactivity_pre-processed_data.csv  sample_data

# %%
! head bioactivity_pre-processed_data.csv
# Out:
# molecule_chembl_id,canonical_smiles,bioactivity_class,standard_value
# CHEMBL2424677,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)c(Nc4ccccc4)c3)cc2C1,inactive,10000.0
# CHEMBL2426376,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)cc3Nc3ccccc3)cc2C1,inactive,10000.0
# CHEMBL2426375,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(C5CCCN5)CC4)cc3)cc2C1,inactive,10000.0
# CHEMBL2426374,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CC5CCC(C4)C5N4CCCC4)cc3)cc2C1,inactive,10000.0
# CHEMBL2426373,CCN1Cc2ccc(NC(=O)c3ccc(C(=O)N4CCC(N5CCCC5)CC4)cc3)cc2C1,inactive,10000.0
# CHEMBL2426368,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(-c2ccccc2)c1)N1CCC(N2CCCC2)CC1,inactive,10000.0
# CHEMBL2426367,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Oc2ccccc2)c1)N1CCC(N2CCCC2)CC1,inactive,10000.0
# CHEMBL2426366,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(Cc2ccccc2)c1)N1CCC(N2CCCC2)CC1,inactive,10000.0
# CHEMBL2426365,O=C(c1ccc(C(=O)N2CCC(N3CCCC3)CC2)c(NCc2ccccc2)c1)N1CCC(N2CCCC2)CC1,inactive,10000.0
